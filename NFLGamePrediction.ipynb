# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('spreadspoke_scores.csv')
# df = df[['score_home', 'score_away']]
df['score_differential'] = df['score_home']-df['score_away']
plt.hist(df['score_differential'], bins = 75)
plt.title('NFL Season Point Differential of All Games')
plt.xlabel('Point differentail (Home Team Score - Away Team Score)')
plt.ylabel('Occurences')
plt.show()
#11877:12144

# %%
df = df.iloc[11877:12144]
plt.hist(df['score_differential'], bins = 25)
plt.title('2017 NFL Season Point Differential')
plt.xlabel('Point differentail (Home Team Score - Away Team Score)')
plt.ylabel('Occurences')
plt.show()

# %%
for i in df:
    if df['team_home'] == 'New England Patriots':
        df['team_home'] = 'NE'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-6f36c236be8d> in <module>
#       1 for i in df:
# ----> 2     if df['team_home'] == 'New England Patriots':
#       3         df['team_home'] = 'NE'
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1327
#    1328     def __nonzero__(self):
# -> 1329         raise ValueError(
#    1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
